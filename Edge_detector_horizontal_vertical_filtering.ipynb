# %% [markdown]
# # Applying Vertical and Horizontal Filters on a Image

# %%
from sklearn.datasets import load_sample_image
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cv2

# %%
flower = load_sample_image("flower.jpg")
plt.imshow(flower);

# %%
gray_flower = cv2.cvtColor(flower,cv2.COLOR_RGB2GRAY)
plt.imshow(gray_china, cmap='gray');

# %%
vertical_filter = np.array([[1,0,-1],[1,0,-1],[1,0,-1]])
horizontal_filter = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])

# %%
vertical_filter
# Out:
# array([[ 1,  0, -1],
#        [ 1,  0, -1],
#        [ 1,  0, -1]])

# %%
horizontal_filter
# Out:
# array([[ 1,  1,  1],
#        [ 0,  0,  0],
#        [-1, -1, -1]])

# %% [markdown]
# # Vertical Filter

# %%
plt.imshow(cv2.filter2D(gray_flower,-1,vertical_filter), cmap='gray');

# %% [markdown]
# # Horizontal Filtering

# %%
plt.imshow(cv2.filter2D(gray_flower,-1,horizontal_filter), cmap='gray');
